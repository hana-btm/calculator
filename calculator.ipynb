# %%
import math 
from colorama import Fore, Style
operation1=input('''Select the desired operation= 
                 'L'=log in
                 'E'=exit
                 ''')
list_operation=['t','m','s','d','sqrt','e']
c =0
loop2=True
loop3=True
loop4=True
while True:
    if operation1.lower() in ['l']:
        while loop2:
            if c ==0:
                operation=input('''Select the desired operation= 
                                't'=total
                                'm'=multiplication
                                's'=Submission
                                'sqrt'=square
                                'd'=division
                                'e'=exit
                                ''')
            #Operations review
            while operation.lower()=='e':
                if loop3:
                    exit=input('''Are you sure? 
                    Please type Y for YES or N for NO. ''')
                    #Exit the calculator
                    if exit.lower()=="y":
                        print(Fore.BLACK+"exit")
                        print(Fore.BLACK+"good time")
                        print(Style.RESET_ALL)
                        loop3=False
                    elif exit.lower()=="n":
                        operation=input('''Select the desired operation=
                                        't'=total
                                        'm'=multiplication
                                        's'=Submission
                                        'd'=division
                                        'sqrt'=square
                                        'e'=exit
                                        ''')
                    else:
                        print(Fore.RED+"again")
                        print(Style.RESET_ALL)
            #Out-of-range operations
            while operation.lower() not in list_operation:
                print(Fore.RED+"please Try again")
                print(Style.RESET_ALL)
                operation=input('''Select the desired operation=
                                't'=total
                                'm'=multiplication
                                's'=Submission
                                'd'=division
                                'sqrt'=square
                                'e'=exit
                                ''')
                while operation.lower()=='e':
                    if loop3:
                        exit=input('''Are you sure? 
                        Please type Y for YES or N for NO. ''')
                        if exit.lower()=="y":
                            print(Fore.BLACK+"exit")
                            print(Fore.BLACK+"good time")
                            print(Style.RESET_ALL)
                            loop3=False
                        elif exit.lower()=="n":
                            operation=input('''Select the desired operation=
                                            't'=total
                                            'm'=multiplication
                                            's'=Submission
                                            'd'=division
                                            'sqrt'=square
                                            'e'=exit
                                            ''')
                        else:
                            print(Fore.RED+"again")
                            print(Style.RESET_ALL)    
            while operation.lower()=='sqrt':
                #Enter a positive number
                while loop4:
                    number=input("please enter your the number: ")
                    try:
                        number=float(number)
                        break
                    except:
                        print("Please enter the number again")
                        continue
                if number>0:
                    print(Fore.BLUE+"square= ",math.sqrt (number))
                    print(Style.RESET_ALL)
                else:
                    continue
                operation=input('''Select the desired operation= 
                                't'=total
                                'm'=multiplication
                                's'=Submission
                                'd'=division
                                'sqrt'=square
                                'e'=exit
                                ''')
                while operation.lower()=='e':
                    if loop3:
                        exit=input('''Are you sure? 
                        Please type Y for YES or N for NO. ''')
                        #Exit the calculator
                        if exit.lower()=="y":
                            print(Fore.BLACK+"exit")
                            print(Fore.BLACK+"good time")
                            print(Style.RESET_ALL)
                            loop3=False
                        elif exit.lower()=="n":
                            operation=input('''Select the desired operation=
                                            't'=total
                                            'm'=multiplication
                                            's'=Submission
                                            'd'=division
                                            'sqrt'=square
                                            'e'=exit
                                            ''')
                        else:
                            print(Fore.RED+"again")
                            print(Style.RESET_ALL)
            #Enter 2 positive numbers                
            while True:
                number1=input("please enter your the first number: ")
                try:
                    number1=float(number1)
                    break
                except:
                    print("Please enter the number again")
                    continue
            while True:
                number2 =input("please enter your the second number: ")
                try:
                    number2=float(number2)
                    break
                except:
                    print("Please enter the number again")
                    continue    
            if operation.lower()=='t':
                print(Fore.BLUE+"total= ", number1+number2)
                print(Style.RESET_ALL)
            if operation.lower()=='m':
                print(Fore.GREEN+ "multiplication= ", number1*number2)
                print(Style.RESET_ALL)
            if operation.lower()=='s':
                print(Fore.YELLOW +"Submission= ", number1 - number2)
                print(Style.RESET_ALL)
            if operation.lower()=='d':
                if number2==0:
                    print("error")
                else:
                    print(Fore.GREEN+"division= ", number1 /number2)
                    print(Style.RESET_ALL)
            while operation.lower()=='e':
                if loop3:
                    exit=input('''Are you sure? 
                                Please type Y for YES or N for NO. ''')
                    #Exit the calculator
                    if exit.lower()=="y":
                        print(Fore.BLACK+"exit")
                        print(Fore.BLACK+"good time")
                        print(Style.RESET_ALL)
                        loop3=False
                    elif exit.lower()=="n":
                        operation=input('''Select the desired operation=
                                        't'=total
                                        'm'=multiplication
                                        's'=Submission
                                        'd'=division
                                        'sqrt'=square
                                        'e'=exit
                                        ''')
                    else:
                        print(Fore.RED+"again")
                        print(Style.RESET_ALL)  
           
            c +=1    
            operation=input('''Select the desired operation= 
                            't'=total
                            'm'=multiplication
                            's'=Submission
                            'd'=division
                            'sqrt'=square
                            'e'=exit
                            ''')
    elif operation1.lower()=='e':
        print(Fore.BLACK+"exit")
        print(Style.RESET_ALL)
        
        again = input('''Do you want to calculate ?
                      Please type Y for YES or N for NO.
                      ''')
        if again.lower()=="y":
            operation1=input('''Select the desired operation= 
                             'L'=log in
                             'E'=exit
                             ''')
        #Exit the calculator
        elif again.lower()=="n":
            print("good time")
            break
        else:
            print(Fore.RED+"again")
            print(Style.RESET_ALL)        
    else:
        print(Fore.RED+"error")
        print(Style.RESET_ALL)
        operation1=input('''Select the desired operation= 
                         'L'=log in
                         'E'=exit
                         ''')
